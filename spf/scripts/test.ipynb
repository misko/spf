# %%
from spf.dataset.spf_dataset import v5spfdataset


ds_fn = "/mnt/md1/2d_wallarray_v2_data/june_fix/wallarrayv3_2024_08_04_20_09_14_nRX2_rx_circle_spacing0p05075.zarr"
ds = v5spfdataset(
    ds_fn,
    nthetas=65,
    precompute_cache=None,
    skip_fields=set(["signal_matrix"]),
    ignore_qc=True,
    segment_if_not_exist=False,
    temp_file=True,
    temp_file_suffix=""
)

# %%
ds.carrier_frequencies, len(ds)

# %%
ds.rx_spacing

# %%
ds.yaml_config['routine']
